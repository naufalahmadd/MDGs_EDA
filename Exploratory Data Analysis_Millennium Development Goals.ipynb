# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Millenium Development Goals.csv')

# %%
df.shape
# Out:
# (6580, 136)

# %%
pd.options.display.max_seq_items = None
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Time', 'Time Code',
#        '% of females having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions) [SH.HIV.KNOW.FE.ZS]',
#        '% of males having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions) [SH.HIV.KNOW.MA.ZS]',
#        'Adjusted net enrollment rate, primary (% of primary school age children) [SE.PRM.TENR]',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]',
#        'Agricultural support estimate (% of GDP) [NY.AGR.SUBS.GD.ZS]',
#        'AIDS estimated deaths (UNAIDS estimates) [SH.DYN.AIDS.DH]',
#        'Annual freshwater withdrawals, total (% of internal resources) [ER.H2O.FWTL.ZS]',
#        'Antiretroviral therapy coverage (% of people living with HIV) [SH.HIV.ARTC.ZS]',
#        'ARI treatment (% of children under 5 taken to a health provider) [SH.STA.ARIC.ZS]',
#        'Average tariffs imposed by developed countries on agricultural products from developing countries (%) [TM.TAX.AGRI.CD.DV]',
#        'Average tariffs imposed by developed countries on agricultural products from least developed countries (%) [TM.TAX.AGRI.CD.LD]',
#        'Average tariffs imposed by developed countries on clothing products from developing countries (%) [TM.TAX.CLTH.CD.DV]',
#        'Average tariffs imposed by developed countries on clothing products from least developed countries (%) [TM.TAX.CLTH.CD.LD]',
#        'Average tariffs imposed by developed countries on textile products from developing countries (%) [TM.TAX.TXTL.CD.DV]',
#        'Average tariffs imposed by developed countries on textile products from least developed countries (%) [TM.TAX.TXTL.CD.LD]',
#        'Bilateral ODA commitments that is untied (% of bilateral ODA commitments) [DC.ODA.UNTD.ZS]',
#        'Bilateral ODA commitments that is untied (current US$) [DC.ODA.UNTD.CD]',
#        'Bilateral, sector-allocable ODA to basic social services (% of bilateral ODA commitments) [DC.ODA.SOCL.ZS]',
#        'Bilateral, sector-allocable ODA to basic social services (current US$) [DC.ODA.SOCL.CD]',
#        'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]',
#        'Children orphaned by HIV/AIDS [SH.HIV.ORPH]',
#        'Children with fever receiving antimalarial drugs (% of children under age 5 with fever) [SH.MLR.TRET.ZS]',
#        'CO2 emissions (kg per PPP $ of GDP) [EN.ATM.CO2E.PP.GD]',
#        'CO2 emissions (kt) [EN.ATM.CO2E.KT]',
#        'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]',
#        'Comprehensive correct knowledge of HIV/AIDS, ages 15-24, female (2 prevent ways and reject 3 misconceptions) [SH.HIV.1524.KW.FE.ZS]',
#        'Comprehensive correct knowledge of HIV/AIDS, ages 15-24, male (2 prevent ways and reject 3 misconceptions) [SH.HIV.1524.KW.MA.ZS]',
#        'Condom use at last high-risk sex, adult female (% ages 15-49) [SH.CON.AIDS.FE.ZS]',
#        'Condom use at last high-risk sex, adult male (% ages 15-49) [SH.CON.AIDS.MA.ZS]',
#        'Condom use, population ages 15-24, female (% of females ages 15-24) [SH.CON.1524.FE.ZS]',
#        'Condom use, population ages 15-24, male (% of males ages 15-24) [SH.CON.1524.MA.ZS]',
#        'Contraceptive prevalence, any methods (% of women ages 15-49) [SP.DYN.CONU.ZS]',
#        'Contributing family workers, female (% of female employment) [SL.FAM.WORK.FE.ZS]',
#        'Contributing family workers, male (% of male employment) [SL.FAM.WORK.MA.ZS]',
#        'Contributing family workers, total (% of total employment) [SL.FAM.WORK.ZS]',
#        'Debt relief committed under HIPC and MDRI initiatives, cumulative US$ in end-2012 NPV terms [DT.HPC.TOTL.PV]',
#        'Debt relief committed under HIPC initiative, cumulative US$ in end-2012 NPV terms [DT.HPC.COMR.PV]',
#        'Debt relief delivered in full under MDRI initiative, cumulative US$ in end-2012 NPV terms [DT.HPC.MDRI.PV]',
#        'Debt service (PPG and IMF only, % of exports of goods, services and primary income) [DT.TDS.DPPF.XP.ZS]',
#        'Employment to population ratio, 15+, female (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.FE.ZS]',
#        'Employment to population ratio, 15+, male (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.MA.ZS]',
#        'Employment to population ratio, 15+, total (%) (modeled ILO estimate) [SL.EMP.TOTL.SP.ZS]',
#        'Employment to population ratio, ages 15-24, female (%) (modeled ILO estimate) [SL.EMP.1524.SP.FE.ZS]',
#        'Employment to population ratio, ages 15-24, male (%) (modeled ILO estimate) [SL.EMP.1524.SP.MA.ZS]',
#        'Employment to population ratio, ages 15-24, total (%) (modeled ILO estimate) [SL.EMP.1524.SP.ZS]',
#        'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP) [EG.USE.COMM.GD.PP.KD]',
#        'Fertility rate, total (births per woman) [SP.DYN.TFRT.IN]',
#        'Fixed telephone subscriptions (per 100 people) [IT.MLT.MAIN.P2]',
#        'Forest area (% of land area) [AG.LND.FRST.ZS]',
#        'Forest area (sq. km) [AG.LND.FRST.K2]',
#        'GDP per person employed (constant 2011 PPP $) [SL.GDP.PCAP.EM.KD]',
#        'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent) [EG.GDP.PUSE.KO.PP.KD]',
#        'GNI per capita, Atlas method (current US$) [NY.GNP.PCAP.CD]',
#        'GNI, Atlas method (current US$) [NY.GNP.ATLS.CD]',
#        'Goods (excluding arms) admitted free of tariffs from developing countries (% total merchandise imports excluding arms) [TM.MRC.NOTX.DV.ZS]',
#        'Goods (excluding arms) admitted free of tariffs from least developed countries (% total merchandise imports excluding arms) [TM.MRC.NOTX.LD.ZS]',
#        'Gross capital formation (% of GDP) [NE.GDI.TOTL.ZS]',
#        'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]',
#        'Improved sanitation facilities (% of population with access) [SH.STA.ACSN]',
#        'Improved water source (% of population with access) [SH.H2O.SAFE.ZS]',
#        'Incidence of tuberculosis (per 100,000 people) [SH.TBS.INCD]',
#        'Income share held by lowest 20% [SI.DST.FRST.20]',
#        'Internet users (per 100 people) [IT.NET.USER.P2]',
#        'Life expectancy at birth, total (years) [SP.DYN.LE00.IN]',
#        'Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]',
#        'Literacy rate, youth female (% of females ages 15-24) [SE.ADT.1524.LT.FE.ZS]',
#        'Literacy rate, youth male (% of males ages 15-24) [SE.ADT.1524.LT.MA.ZS]',
#        'Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]',
#        'Marine protected areas (% of territorial waters) [ER.MRN.PTMR.ZS]',
#        'Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]',
#        'Mobile cellular subscriptions (per 100 people) [IT.CEL.SETS.P2]',
#        'Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]',
#        'Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]',
#        'Net ODA provided to the least developed countries (% of donor GNI) [DC.ODA.TLDC.GN.ZS]',
#        'Net ODA provided to the least developed countries (current US$) [DC.ODA.TLDC.CD]',
#        'Net ODA provided, total (% of GNI) [DC.ODA.TOTL.GN.ZS]',
#        'Net ODA provided, total (constant 2015 US$) [DC.ODA.TOTL.KD]',
#        'Net ODA provided, total (current US$) [DC.ODA.TOTL.CD]',
#        'Net ODA received (% of GNI) [DT.ODA.ODAT.GN.ZS]',
#        'Net ODA received per capita (current US$) [DT.ODA.ODAT.PC.ZS]',
#        'Net official development assistance and official aid received (current US$) [DT.ODA.ALLD.CD]',
#        'Net official development assistance received (current US$) [DT.ODA.ODAT.CD]',
#        'Persistence to last grade of primary, female (% of cohort) [SE.PRM.PRSL.FE.ZS]',
#        'Persistence to last grade of primary, male (% of cohort) [SE.PRM.PRSL.MA.ZS]',
#        'Persistence to last grade of primary, total (% of cohort) [SE.PRM.PRSL.ZS]',
#        'Population living in slums (% of urban population) [EN.POP.SLUM.UR.ZS]',
#        'Population, total [SP.POP.TOTL]',
#        'Poverty gap at $1.90 a day (2011 PPP) (%) [SI.POV.GAPS]',
#        'Poverty gap at national poverty lines (%) [SI.POV.NAGP]',
#        'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population) [SI.POV.DDAY]',
#        'Poverty headcount ratio at national poverty lines (% of population) [SI.POV.NAHC]',
#        'PPP conversion factor, GDP (LCU per international $) [PA.NUS.PPP]',
#        'PPP conversion factor, private consumption (LCU per international $) [PA.NUS.PRVT.PP]',
#        'Pregnant women receiving prenatal care (%) [SH.STA.ANVC.ZS]',
#        'Pregnant women receiving prenatal care of at least four visits (% of pregnant women) [SH.STA.ANV4.ZS]',
#        'Prevalence of HIV, female (% ages 15-24) [SH.HIV.1524.FE.ZS]',
#        'Prevalence of HIV, male (% ages 15-24) [SH.HIV.1524.MA.ZS]',
#        'Prevalence of HIV, total (% of population ages 15-49) [SH.DYN.AIDS.ZS]',
#        'Prevalence of undernourishment (% of population) [SN.ITK.DEFC.ZS]',
#        'Prevalence of underweight, weight for age (% of children under 5) [SH.STA.MALN.ZS]',
#        'Primary completion rate, total (% of relevant age group) [SE.PRM.CMPT.ZS]',
#        'Proportion of seats held by women in national parliaments (%) [SG.GEN.PARL.ZS]',
#        'Ratio of school attendance rate of orphans to school attendance rate of non orphans [SE.ENR.ORPH]',
#        'Renewable internal freshwater resources per capita (cubic meters) [ER.H2O.INTR.PC]',
#        'Reported cases of malaria [SH.STA.MALR]',
#        'Rural poverty gap at national poverty lines (%) [SI.POV.RUGP]',
#        'Rural poverty headcount ratio at national poverty lines (% of rural population) [SI.POV.RUHC]',
#        'School enrollment, primary (% net) [SE.PRM.NENR]',
#        'School enrollment, primary (gross), gender parity index (GPI) [SE.ENR.PRIM.FM.ZS]',
#        'School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]',
#        'School enrollment, secondary (gross), gender parity index (GPI) [SE.ENR.SECO.FM.ZS]',
#        'School enrollment, tertiary (gross), gender parity index (GPI) [SE.ENR.TERT.FM.ZS]',
#        'Self-employed, female (% of female employment) [SL.EMP.SELF.FE.ZS]',
#        'Self-employed, male (% of male employment) [SL.EMP.SELF.MA.ZS]',
#        'Self-employed, total (% of total employment) [SL.EMP.SELF.ZS]',
#        'Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment) [SL.EMP.INSV.FE.ZS]',
#        'Status under enhanced HIPC initiative [DT.HPC.STTS]',
#        'Terrestrial protected areas (% of total land area) [ER.LND.PTLD.ZS]',
#        'Total bilateral ODA commitments (current US$) [DC.ODA.COMM.CD]',
#        'Total bilateral sector allocable ODA commitments (current US$) [DC.ODA.COMM.SA.CD]',
#        'Total debt service (% of exports of goods, services and primary income) [DT.TDS.DECT.EX.ZS]',
#        'Trade (% of GDP) [NE.TRD.GNFS.ZS]',
#        'Tuberculosis case detection rate (%, all forms) [SH.TBS.DTEC.ZS]',
#        'Tuberculosis death rate (per 100,000 people), including HIV [SH.TBS.MORT]',
#        'Tuberculosis treatment success rate (% of new cases) [SH.TBS.CURE.ZS]',
#        'Unmet need for contraception (% of married women ages 15-49) [SP.UWT.TFRT]',
#        'Urban poverty gap at national poverty lines (%) [SI.POV.URGP]',
#        'Urban poverty headcount ratio at national poverty lines (% of urban population) [SI.POV.URHC]',
#        'Use of insecticide-treated bed nets (% of under-5 population) [SH.MLR.NETS.ZS]',
#        'Vulnerable employment, female (% of female employment) [SL.EMP.VULN.FE.ZS]',
#        'Vulnerable employment, male (% of male employment) [SL.EMP.VULN.MA.ZS]',
#        'Vulnerable employment, total (% of total employment) [SL.EMP.VULN.ZS]'],
#       dtype='object')

# %%
df = df[[
    'Country Name', 'Country Code', 'Time', 'Time Code',
    'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population) [SI.POV.DDAY]', 
    'Poverty gap at $1.90 a day (2011 PPP) (%) [SI.POV.GAPS]', 
    'Poverty gap at national poverty lines (%) [SI.POV.NAGP]',
    'Income share held by lowest 20% [SI.DST.FRST.20]',
    'Prevalence of underweight, weight for age (% of children under 5) [SH.STA.MALN.ZS]', 
    'Prevalence of undernourishment (% of population) [SN.ITK.DEFC.ZS]', 
    'School enrollment, primary (% net) [SE.PRM.NENR]',
    'School enrollment, primary (gross), gender parity index (GPI) [SE.ENR.PRIM.FM.ZS]',
    'School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]',
    'School enrollment, secondary (gross), gender parity index (GPI) [SE.ENR.SECO.FM.ZS]',
    'School enrollment, tertiary (gross), gender parity index (GPI) [SE.ENR.TERT.FM.ZS]',
    'Persistence to last grade of primary, female (% of cohort) [SE.PRM.PRSL.FE.ZS]',
    'Persistence to last grade of primary, male (% of cohort) [SE.PRM.PRSL.MA.ZS]',
    'Persistence to last grade of primary, total (% of cohort) [SE.PRM.PRSL.ZS]',
    'Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]',
    'Literacy rate, youth female (% of females ages 15-24) [SE.ADT.1524.LT.FE.ZS]',
    'Literacy rate, youth male (% of males ages 15-24) [SE.ADT.1524.LT.MA.ZS]',
    'Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]',
    'Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment) [SL.EMP.INSV.FE.ZS]',
    'Proportion of seats held by women in national parliaments (%) [SG.GEN.PARL.ZS]',
    'Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]',
    'Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]',
    'Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]',
    'Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]',
    'Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]',
    'Prevalence of HIV, female (% ages 15-24) [SH.HIV.1524.FE.ZS]',
    'Prevalence of HIV, male (% ages 15-24) [SH.HIV.1524.MA.ZS]',
    'Prevalence of HIV, total (% of population ages 15-49) [SH.DYN.AIDS.ZS]',
    'Condom use at last high-risk sex, adult female (% ages 15-49) [SH.CON.AIDS.FE.ZS]',
    'Condom use at last high-risk sex, adult male (% ages 15-49) [SH.CON.AIDS.MA.ZS]',
    'Condom use, population ages 15-24, female (% of females ages 15-24) [SH.CON.1524.FE.ZS]',
    'Condom use, population ages 15-24, male (% of males ages 15-24) [SH.CON.1524.MA.ZS]',
    'Contraceptive prevalence, any methods (% of women ages 15-49) [SP.DYN.CONU.ZS]',
    'Children orphaned by HIV/AIDS [SH.HIV.ORPH]',
    'Reported cases of malaria [SH.STA.MALR]',
    'Children with fever receiving antimalarial drugs (% of children under age 5 with fever) [SH.MLR.TRET.ZS]',
    'Tuberculosis case detection rate (%, all forms) [SH.TBS.DTEC.ZS]',
    'Tuberculosis death rate (per 100,000 people), including HIV [SH.TBS.MORT]',
    'Tuberculosis treatment success rate (% of new cases) [SH.TBS.CURE.ZS]',
    'Incidence of tuberculosis (per 100,000 people) [SH.TBS.INCD]',
    'Forest area (% of land area) [AG.LND.FRST.ZS]',
    'Forest area (sq. km) [AG.LND.FRST.K2]',
    'Marine protected areas (% of territorial waters) [ER.MRN.PTMR.ZS]',
    'Terrestrial protected areas (% of total land area) [ER.LND.PTLD.ZS]',
    'Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP) [EG.USE.COMM.GD.PP.KD]',
    'GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent) [EG.GDP.PUSE.KO.PP.KD]',
    'CO2 emissions (kg per PPP $ of GDP) [EN.ATM.CO2E.PP.GD]',
    'CO2 emissions (kt) [EN.ATM.CO2E.KT]',
    'CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]', 
    'Improved water source (% of population with access) [SH.H2O.SAFE.ZS]'
]]

# %%
df.tail(10)
# Out:
#                                           Country Name Country Code    Time  \
# 6570                                          Zimbabwe          ZWE  2011.0
# 6571                                          Zimbabwe          ZWE  2012.0
# 6572                                          Zimbabwe          ZWE  2013.0
# 6573                                          Zimbabwe          ZWE  2014.0
# 6574                                          Zimbabwe          ZWE  2015.0
# 6575                                               NaN          NaN     NaN
# 6576                                               NaN          NaN     NaN
# 6577                                               NaN          NaN     NaN
# 6578  Data from database: Millennium Development Goals          NaN     NaN
# 6579                          Last Updated: 09/19/2018          NaN     NaN
#
#      Time Code  \
# 6570    YR2011
# 6571    YR2012
# 6572    YR2013
# 6573    YR2014
# 6574    YR2015
# 6575       NaN
# 6576       NaN
# 6577       NaN
# 6578       NaN
# 6579       NaN
#
#      Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population) [SI.POV.DDAY]  \
# 6570                                               21.4
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Poverty gap at $1.90 a day (2011 PPP) (%) [SI.POV.GAPS]  \
# 6570                                                5.2
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Poverty gap at national poverty lines (%) [SI.POV.NAGP]  \
# 6570                                                 ..
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Income share held by lowest 20% [SI.DST.FRST.20]  \
# 6570                                              5.8
# 6571                                               ..
# 6572                                               ..
# 6573                                               ..
# 6574                                               ..
# 6575                                              NaN
# 6576                                              NaN
# 6577                                              NaN
# 6578                                              NaN
# 6579                                              NaN
#
#      Prevalence of underweight, weight for age (% of children under 5) [SH.STA.MALN.ZS]  \
# 6570                                                 ..
# 6571                                                 ..
# 6572                                                 ..
# 6573                                               11.2
# 6574                                                8.4
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Prevalence of undernourishment (% of population) [SN.ITK.DEFC.ZS]  \
# 6570                                               32.7
# 6571                                               34.1
# 6572                                               37.3
# 6573                                               41.3
# 6574                                               44.7
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      School enrollment, primary (% net) [SE.PRM.NENR]  \
# 6570                                               ..
# 6571                                 87.6746520996094
# 6572                                 84.7938995361328
# 6573                                               ..
# 6574                                               ..
# 6575                                              NaN
# 6576                                              NaN
# 6577                                              NaN
# 6578                                              NaN
# 6579                                              NaN
#
#      School enrollment, primary (gross), gender parity index (GPI) [SE.ENR.PRIM.FM.ZS]  \
# 6570                                                 ..
# 6571                                  0.986790001392365
# 6572                                  0.984679996967316
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]  \
# 6570                                                 ..
# 6571                                  0.981429994106293
# 6572                                  0.982420027256012
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      School enrollment, secondary (gross), gender parity index (GPI) [SE.ENR.SECO.FM.ZS]  \
# 6570                                                 ..
# 6571                                  0.970650017261505
# 6572                                  0.980490028858185
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      School enrollment, tertiary (gross), gender parity index (GPI) [SE.ENR.TERT.FM.ZS]  \
# 6570                                  0.755760014057159
# 6571                                  0.766139984130859
# 6572                                  0.840030014514923
# 6573                                                 ..
# 6574                                  0.899089992046356
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Persistence to last grade of primary, female (% of cohort) [SE.PRM.PRSL.FE.ZS]  \
# 6570                                                 ..
# 6571                                   78.4168090820313
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Persistence to last grade of primary, male (% of cohort) [SE.PRM.PRSL.MA.ZS]  \
# 6570                                                 ..
# 6571                                   75.4824295043945
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Persistence to last grade of primary, total (% of cohort) [SE.PRM.PRSL.ZS]  \
# 6570                                                 ..
# 6571                                   76.9268798828125
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]  \
# 6570                                   83.5827102661133
# 6571                                                 ..
# 6572                                                 ..
# 6573                                   88.6934204101563
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Literacy rate, youth female (% of females ages 15-24) [SE.ADT.1524.LT.FE.ZS]  \
# 6570                                   92.1245574951172
# 6571                                                 ..
# 6572                                                 ..
# 6573                                    93.188346862793
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Literacy rate, youth male (% of males ages 15-24) [SE.ADT.1524.LT.MA.ZS]  \
# 6570                                   89.5905838012695
# 6571                                                 ..
# 6572                                                 ..
# 6573                                   87.5918579101563
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]  \
# 6570                                   90.9307022094727
# 6571                                                 ..
# 6572                                                 ..
# 6573                                   90.4281234741211
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment) [SL.EMP.INSV.FE.ZS]  \
# 6570                                               33.9
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Proportion of seats held by women in national parliaments (%) [SG.GEN.PARL.ZS]  \
# 6570                                                 15
# 6571                                                 15
# 6572                                               31.5
# 6573                                               31.5
# 6574                                               31.5
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]  \
# 6570                                               52.2
# 6571                                               48.4
# 6572                                               45.4
# 6573                                               42.3
# 6574                                               40.2
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]  \
# 6570                                               81.2
# 6571                                               73.8
# 6572                                               66.8
# 6573                                               61.1
# 6574                                                 57
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]  \
# 6570                                                 92
# 6571                                                 97
# 6572                                                 93
# 6573                                                 92
# 6574                                                 86
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]  \
# 6570                                                409
# 6571                                                379
# 6572                                                369
# 6573                                                401
# 6574                                                443
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 6570                                               66.2
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 80
# 6574                                               78.1
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Prevalence of HIV, female (% ages 15-24) [SH.HIV.1524.FE.ZS]  \
# 6570                                                7.4
# 6571                                                7.4
# 6572                                                7.3
# 6573                                                7.1
# 6574                                                6.8
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Prevalence of HIV, male (% ages 15-24) [SH.HIV.1524.MA.ZS]  \
# 6570                                                3.6
# 6571                                                3.6
# 6572                                                3.6
# 6573                                                3.6
# 6574                                                3.5
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Prevalence of HIV, total (% of population ages 15-49) [SH.DYN.AIDS.ZS]  \
# 6570                                               14.8
# 6571                                               14.6
# 6572                                               14.4
# 6573                                               14.2
# 6574                                                 14
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Condom use at last high-risk sex, adult female (% ages 15-49) [SH.CON.AIDS.FE.ZS]  \
# 6570                                               57.6
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                               66.7
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Condom use at last high-risk sex, adult male (% ages 15-49) [SH.CON.AIDS.MA.ZS]  \
# 6570                                               77.4
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                               85.4
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Condom use, population ages 15-24, female (% of females ages 15-24) [SH.CON.1524.FE.ZS]  \
# 6570                                               12.1
# 6571                                                 ..
# 6572                                                 ..
# 6573                                               43.4
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Condom use, population ages 15-24, male (% of males ages 15-24) [SH.CON.1524.MA.ZS]  \
# 6570                                               51.8
# 6571                                                 ..
# 6572                                                 ..
# 6573                                               64.6
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Contraceptive prevalence, any methods (% of women ages 15-49) [SP.DYN.CONU.ZS]  \
# 6570                                               58.5
# 6571                                                 ..
# 6572                                                 ..
# 6573                                               66.9
# 6574                                               66.8
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Children orphaned by HIV/AIDS [SH.HIV.ORPH]  \
# 6570                                      740000
# 6571                                      690000
# 6572                                      640000
# 6573                                      580000
# 6574                                      530000
# 6575                                         NaN
# 6576                                         NaN
# 6577                                         NaN
# 6578                                         NaN
# 6579                                         NaN
#
#      Reported cases of malaria [SH.STA.MALR]  \
# 6570                                  319935
# 6571                                  276963
# 6572                                  422633
# 6573                                  535931
# 6574                                  391651
# 6575                                     NaN
# 6576                                     NaN
# 6577                                     NaN
# 6578                                     NaN
# 6579                                     NaN
#
#      Children with fever receiving antimalarial drugs (% of children under age 5 with fever) [SH.MLR.TRET.ZS]  \
# 6570                                                2.3
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                  3
# 6574                                                  1
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Tuberculosis case detection rate (%, all forms) [SH.TBS.DTEC.ZS]  \
# 6570                                                 70
# 6571                                                 68
# 6572                                                 72
# 6573                                                 69
# 6574                                                 71
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Tuberculosis death rate (per 100,000 people), including HIV [SH.TBS.MORT]  \
# 6570                                                 15
# 6571                                                 15
# 6572                                                 13
# 6573                                                 13
# 6574                                                 11
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Tuberculosis treatment success rate (% of new cases) [SH.TBS.CURE.ZS]  \
# 6570                                                 80
# 6571                                                 81
# 6572                                                 80
# 6573                                                 81
# 6574                                                 81
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Incidence of tuberculosis (per 100,000 people) [SH.TBS.INCD]  \
# 6570                                                384
# 6571                                                355
# 6572                                                304
# 6573                                                278
# 6574                                                242
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Forest area (% of land area) [AG.LND.FRST.ZS]  \
# 6570                              39.5801990435569
# 6571                               38.772650898281
# 6572                               37.965102753005
# 6573                              37.1575546077291
# 6574                              36.3500064624532
# 6575                                           NaN
# 6576                                           NaN
# 6577                                           NaN
# 6578                                           NaN
# 6579                                           NaN
#
#      Forest area (sq. km) [AG.LND.FRST.K2]  \
# 6570                                153116
# 6571                                149992
# 6572                                146868
# 6573                                143744
# 6574                                140620
# 6575                                   NaN
# 6576                                   NaN
# 6577                                   NaN
# 6578                                   NaN
# 6579                                   NaN
#
#      Marine protected areas (% of territorial waters) [ER.MRN.PTMR.ZS]  \
# 6570                                                 ..
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Terrestrial protected areas (% of total land area) [ER.LND.PTLD.ZS]  \
# 6570                                                 ..
# 6571                                                 ..
# 6572                                                 ..
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP) [EG.USE.COMM.GD.PP.KD]  \
# 6570                                   427.429041821727
# 6571                                   392.673859533269
# 6572                                   388.475855415833
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent) [EG.GDP.PUSE.KO.PP.KD]  \
# 6570                                   2.33956961777315
# 6571                                   2.54664265451385
# 6572                                   2.57416255362789
# 6573                                                 ..
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      CO2 emissions (kg per PPP $ of GDP) [EN.ATM.CO2E.PP.GD]  \
# 6570                                  0.398737712643853
# 6571                                  0.277937299139419
# 6572                                  0.388354233131711
# 6573                                  0.384589961913686
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      CO2 emissions (kt) [EN.ATM.CO2E.KT]  \
# 6570                            9563.536
# 6571                            7792.375
# 6572                           11675.728
# 6573                           12020.426
# 6574                                  ..
# 6575                                 NaN
# 6576                                 NaN
# 6577                                 NaN
# 6578                                 NaN
# 6579                                 NaN
#
#      CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]  \
# 6570                                   0.66475076996735
# 6571                                  0.529703430657123
# 6572                                  0.775563675088375
# 6573                                  0.779955845162839
# 6574                                                 ..
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN
#
#      Improved water source (% of population with access) [SH.H2O.SAFE.ZS]
# 6570                                               77.7
# 6571                                               77.5
# 6572                                               77.3
# 6573                                               77.1
# 6574                                               76.9
# 6575                                                NaN
# 6576                                                NaN
# 6577                                                NaN
# 6578                                                NaN
# 6579                                                NaN

# %%
df = df.drop(df.index[6575:6580])

# %%
df.head()
# Out:
#   Country Name Country Code    Time Time Code  \
# 0  Afghanistan          AFG  1991.0    YR1991
# 1  Afghanistan          AFG  1992.0    YR1992
# 2  Afghanistan          AFG  1993.0    YR1993
# 3  Afghanistan          AFG  1994.0    YR1994
# 4  Afghanistan          AFG  1995.0    YR1995
#
#   Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population) [SI.POV.DDAY]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Poverty gap at $1.90 a day (2011 PPP) (%) [SI.POV.GAPS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Poverty gap at national poverty lines (%) [SI.POV.NAGP]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Income share held by lowest 20% [SI.DST.FRST.20]  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Prevalence of underweight, weight for age (% of children under 5) [SH.STA.MALN.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Prevalence of undernourishment (% of population) [SN.ITK.DEFC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   School enrollment, primary (% net) [SE.PRM.NENR]  \
# 0                                              NaN
# 1                                              NaN
# 2                                 28.1712093353271
# 3                                              NaN
# 4                                              NaN
#
#   School enrollment, primary (gross), gender parity index (GPI) [SE.ENR.PRIM.FM.ZS]  \
# 0                                  0.547919988632202
# 1                                                NaN
# 2                                  0.351740002632141
# 3                                  0.503340005874634
# 4                                  0.512310028076172
#
#   School enrollment, primary and secondary (gross), gender parity index (GPI) [SE.ENR.PRSC.FM.ZS]  \
# 0                                  0.537329971790314
# 1                                                NaN
# 2                                  0.360570013523102
# 3                                  0.430079996585846
# 4                                  0.471689999103546
#
#   School enrollment, secondary (gross), gender parity index (GPI) [SE.ENR.SECO.FM.ZS]  \
# 0                                  0.512220025062561
# 1                                                NaN
# 2                                  0.380140006542206
# 3                                  0.280339986085892
# 4                                  0.373609989881516
#
#   School enrollment, tertiary (gross), gender parity index (GPI) [SE.ENR.TERT.FM.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Persistence to last grade of primary, female (% of cohort) [SE.PRM.PRSL.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Persistence to last grade of primary, male (% of cohort) [SE.PRM.PRSL.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Persistence to last grade of primary, total (% of cohort) [SE.PRM.PRSL.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Literacy rate, adult total (% of people ages 15 and above) [SE.ADT.LITR.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Literacy rate, youth female (% of females ages 15-24) [SE.ADT.1524.LT.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Literacy rate, youth male (% of males ages 15-24) [SE.ADT.1524.LT.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Literacy rate, youth total (% of people ages 15-24) [SE.ADT.1524.LT.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Share of women in wage employment in the nonagricultural sector (% of total nonagricultural employment) [SL.EMP.INSV.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Proportion of seats held by women in national parliaments (%) [SG.GEN.PARL.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Mortality rate, infant (per 1,000 live births) [SP.DYN.IMRT.IN]  \
# 0                                              115.1
# 1                                              111.4
# 2                                              108.1
# 3                                                105
# 4                                              102.2
#
#   Mortality rate, under-5 (per 1,000 live births) [SH.DYN.MORT]  \
# 0                                              168.9
# 1                                              162.9
# 2                                              157.4
# 3                                              152.4
# 4                                              147.8
#
#   Immunization, measles (% of children ages 12-23 months) [SH.IMM.MEAS]  \
# 0                                                 19
# 1                                                 22
# 2                                                 25
# 3                                                 40
# 4                                                 41
#
#   Maternal mortality ratio (modeled estimate, per 100,000 live births) [SH.STA.MMRT]  \
# 0                                               1330
# 1                                               1330
# 2                                               1320
# 3                                               1300
# 4                                               1270
#
#   Births attended by skilled health staff (% of total) [SH.STA.BRTC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Prevalence of HIV, female (% ages 15-24) [SH.HIV.1524.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Prevalence of HIV, male (% ages 15-24) [SH.HIV.1524.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Prevalence of HIV, total (% of population ages 15-49) [SH.DYN.AIDS.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Condom use at last high-risk sex, adult female (% ages 15-49) [SH.CON.AIDS.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Condom use at last high-risk sex, adult male (% ages 15-49) [SH.CON.AIDS.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Condom use, population ages 15-24, female (% of females ages 15-24) [SH.CON.1524.FE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Condom use, population ages 15-24, male (% of males ages 15-24) [SH.CON.1524.MA.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Contraceptive prevalence, any methods (% of women ages 15-49) [SP.DYN.CONU.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Children orphaned by HIV/AIDS [SH.HIV.ORPH]  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Reported cases of malaria [SH.STA.MALR]  \
# 0                                  297605
# 1                                     NaN
# 2                                     NaN
# 3                                   88302
# 4                                     NaN
#
#   Children with fever receiving antimalarial drugs (% of children under age 5 with fever) [SH.MLR.TRET.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tuberculosis case detection rate (%, all forms) [SH.TBS.DTEC.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tuberculosis death rate (per 100,000 people), including HIV [SH.TBS.MORT]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Tuberculosis treatment success rate (% of new cases) [SH.TBS.CURE.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Incidence of tuberculosis (per 100,000 people) [SH.TBS.INCD]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Forest area (% of land area) [AG.LND.FRST.ZS]  \
# 0                              2.06782464846981
# 1                              2.06782464846981
# 2                              2.06782464846981
# 3                              2.06782464846981
# 4                              2.06782464846981
#
#   Forest area (sq. km) [AG.LND.FRST.K2]  \
# 0                                 13500
# 1                                 13500
# 2                                 13500
# 3                                 13500
# 4                                 13500
#
#    Marine protected areas (% of territorial waters) [ER.MRN.PTMR.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Terrestrial protected areas (% of total land area) [ER.LND.PTLD.ZS]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Energy use (kg of oil equivalent) per $1,000 GDP (constant 2011 PPP) [EG.USE.COMM.GD.PP.KD]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   GDP per unit of energy use (constant 2011 PPP $ per kg of oil equivalent) [EG.GDP.PUSE.KO.PP.KD]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emissions (kg per PPP $ of GDP) [EN.ATM.CO2E.PP.GD]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   CO2 emissions (kt) [EN.ATM.CO2E.KT]  \
# 0                            2438.555
# 1                             1393.46
# 2                            1345.789
# 3                            1294.451
# 4                            1243.113
#
#   CO2 emissions (metric tons per capita) [EN.ATM.CO2E.PC]  \
# 0                                  0.187672723698956
# 1                                 0.0996664742897102
# 2                                 0.0891540360218903
# 3                                 0.0800391696659047
# 4                                 0.0726986180506249
#
#   Improved water source (% of population with access) [SH.H2O.SAFE.ZS]
# 0                                               21.2
# 1                                               21.3
# 2                                               21.4
# 3                                               21.4
# 4                                               21.5

# %%
df = df.replace('..', np.nan)

# %%
print(df.shape)
print(df.duplicated().sum())
print(df.isnull().sum().sum())
# Out:
# 0
# 172842
